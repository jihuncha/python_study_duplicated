# %%
#dijkstra

INF = int(1e9)

n,m = map(int, input().split())

start = int(input())

graph = [[] for i in range(n+1)]

visited = [False] * (n + 1)

distance = [INF] * (n+1)

for make_graph in range(m):
    a,b,c = map(int, input().split())
    
    graph[a].append((b,c))

def smallest_node():
    min_value = INF
    index = 0
    
    for check in range(1, n+1):
        if distance[check] < min_value and not visited[check]:
            min_value = distance[check]
            index = check
    return index

# print(graph)

def dijkstra(start):
    distance[start] = 0
    visited[start] = True
    
    for mapping in graph[start]:
        distance[mapping[0]] = mapping[1]
        
    for i in range(n-1):
        now = smallest_node()
        visited[now] = True
        
        for j in graph[now]:
            cost = distance[now]+j[1]
            
            if cost < distance[j[0]]:
                distance[j[0]] = cost

dijkstra(start)

for result in range(1, n+1):
    if distance[result] == INF:
        print("INF!!!")
    else:
        print(distance[result])
# Out:
# 6 11
# 1
# 1 2 2
# 1 3 5
# 1 4 1
# 2 3 3
# 2 4 2
# 3 2 3
# 3 6 5
# 4 3 3
# 4 5 1
# 5 3 1
# 5 6 2
# 0
# 2
# 3
# 1
# 2
# 4

# %%
6 11
1
1 2 2
1 3 5
1 4 1
2 3 3 
2 4 2
3 2 3
3 6 5
4 3 3
4 5 1
5 3 1 
5 6 2

# %%
# 무한대
INF = int(1e9)
#노드와 간선 정보를 입력받음
n,m = map(int, input().split())

#시작 노드 벉호를 입력받는다.
start = int(input())

#graph를 담을 곳 -> 노드의 갯수 만큼
graph = [[] for _ in range(n+1)]

#방문여부체크
visited = [False] * (n+1)

#최단경로
d = [INF] * (n+1)

#그래프 생성
for make_graph in range(m):
    a,b,c = map(int,input().split())
    graph[a].append((b,c))

def get_smallest_node():
    min_value = INF
    index = 0
    
    for i in range(n+1):
        if d[i] < min_value and not visited[i]:
            min_value = d[i]
            index = i
    return index

def dijkstra(start):
    #방문처리를수행한다.
    d[start] = 0
    visited[start] = True
    #인접한 노드들 값 대입
    for i in graph[start]:
        d[i[0]] = i[1]
    
    for i in range(n-1):
        now = get_smallest_node()
        visited[now] = True
        
        for j in graph[now]:
            cost = d[now] + j[1]
            if cost < d[j[0]]:
                d[j[0]] = cost

dijkstra(start)

for i in range(1, n+1):
    if d[i] == INF:
        print('INF!!!')
    else:
        print(d[i])
# Out:
# 6 11
# 1
# 1 2 2
# 1 3 5
# 1 4 1
# 2 3 3
# 2 4 2
# 3 2 3
# 3 6 5
# 4 3 3
# 4 5 1
# 5 3 1
# 5 6 2
# 0
# 2
# 3
# 1
# 2
# 4

# %%
6 11
1
1 2 2
1 3 5
1 4 1
2 3 3 
2 4 2
3 2 3
3 6 5
4 3 3
4 5 1
5 3 1 
5 6 2

# %%
#노드와 간선
n,m = map(int, input().split())
#시작노드
start = int(input())
# 초기 거리 무한대로 설정
INF = int(1e9)
# 빈 graph 생성
graph = [[] for _ in range(n + 1)]
# 방문여부
visited = [False] * (n+1)
# 거리
distance = [INF] * (n + 1)

#간선 정보 입력
for i in range(m):
    a,b,c = map(int, input().split())
    graph[a].append((b,c))

#가장 가까운 경로인 index 입력받기
def get_smallest_node():
    min_value = INF
    index = 0
    
    for i in range(1, n+1):
        if d[i] < min_value and not visited[i]:
            min_value = d[i]
            index = i
    return index

def dijkstra(start):
    #시작점 방문 처리
    d[start] = 0
    visited[start] = True
    
    #graph 에서 인접 노드 체크
    for check_graph in graph[start]:
        d[check_graph[0]] = check_graph[1]
    
    for i in range(n-1):
        now = get_smallest_node()
        visited[now] = True
        
        for j in graph[now]:
            cost = d[now] + j[1]
            if cost < d[j[0]]:
                d[j[0]] = cost
                
dijkstra(start)

for i in range(1,n+1):
    if d[i] == INF:
        print('INF!!')
    else:
        print(d[i])
# Out:
# 6 11
# 1
# 1 2 2
# 1 3 5
# 1 4 1
# 2 3 3
# 2 4 2
# 3 2 3
# 3 6 5
# 4 3 3
# 4 5 1
# 5 3 1
# 5 6 2
# 0
# 2
# 3
# 1
# 2
# 4

# %%
6 11
1
1 2 2
1 3 5
1 4 1
2 3 3 
2 4 2
3 2 3
3 6 5
4 3 3
4 5 1
5 3 1 
5 6 2

# %%
# improved dijkstra

import heapq

#노드와 간선
n,m = map(int, input().split())
#시작노드
start = int(input())
# 초기 거리 무한대로 설정
INF = int(1e9)
# 빈 graph 생성
graph = [[] for _ in range(n + 1)]
# 거리
distance = [INF] * (n + 1)

#간선 정보 입력
for i in range(m):
    a,b,c = map(int, input().split())
    graph[a].append((b,c))
    
def dijkstra(start):
    q = []
    heapq.heappush(q, (0,start))
    d[start] = 0
    
    while q:
        dist, now = heapq.heappop(q)
        # 이미 처리한 노드라면 무시한다.
        if distance[now] < dist:
            continue
        for i in graph[now]:
            cost = dist + i[1]
            
            if cost < distance[i[0]]:
                distance[i[0]] = cost
                heapq.heappush(q, (cost, i[0]))

# %%
import heapq

test = []
heapq.heappush(test, (-1,2))
heapq.heappush(test, (-9,12))
heapq.heappush(test, (-3,4))

heapq.heappush(test, (-5,6))

print(test)

heapq.heappop(test)

print(test)
# Out:
# [(-9, 12), (-5, 6), (-3, 4), (-1, 2)]
# [(-5, 6), (-1, 2), (-3, 4)]
